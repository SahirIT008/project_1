# %% [markdown]
# <a href="https://colab.research.google.com/github/SahirIT008/project_1/blob/main/Youtube_Data_Harvest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-api-python-client

# %%
import pandas as pd
from googleapiclient.discovery import build

# %%
api_='AIzaSyA7OQjBCHtjN7TSegQxP4OzUMYzDrxRImM'
chID='UCnjU1FHmao9YNfPzE039YTw'

# %%
import pprint
import google_auth_oauthlib.flow
import googleapiclient.discovery
import googleapiclient.errors

scopes = ["https://www.googleapis.com/auth/youtube.readonly"]

api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=api_)

request = youtube.channels().list(
    part="snippet,contentDetails,statistics",
    id=chID
)
response = request.execute()

pprint.pprint(response)
# Out:
# {'etag': 'BtRRFJv_7LmhtB_NvZOfl4-QrKo',
#  'items': [{'contentDetails': {'relatedPlaylists': {'likes': '',
#                                                     'uploads': 'UUnjU1FHmao9YNfPzE039YTw'}},
#             'etag': 'nLHx5mtH1d2DaEvmuKuXheo6RcU',
#             'id': 'UCnjU1FHmao9YNfPzE039YTw',
#             'kind': 'youtube#channel',
#             'snippet': {'country': 'IN',
#                         'customUrl': '@irfansview1',
#                         'description': 'I love Food and Living. So, I vlog and '
#                                        'do Food Reviews.',
#                         'localized': {'description': 'I love Food and Living. '
#                                                      'So, I vlog and do Food '
#                                                      'Reviews.',
#                                       'title': "Irfan's view"},
#                         'publishedAt': '2009-07-13T14:16:41Z',
# ...

# %%
# !pip install google-api-python-client
import googleapiclient.discovery
import pprint

api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=api_
)

request = youtube.playlistItems().list(
    part="snippet,contentDetails",
    maxResults=10000,
    playlistId="PLBCF2DAC6FFB574DE"
)
response = request.execute()
pprint.pprint(response)
# Out:
# ...
# {'etag': 'AjFKzlcLvdnnxRQt6devr7bQ1z4',
#  'items': [{'contentDetails': {'videoId': 'GvgqDSnpRQM',
#                                'videoPublishedAt': '2013-10-18T07:03:29Z'},
#             'etag': 'yUvdhdulONC5Fa12wfTf3uerHwg',
#             'id': 'UExCQ0YyREFDNkZGQjU3NERFLkE2OTA3QzIwNEI3RjYxMDE',
#             'kind': 'youtube#playlistItem',
#             'snippet': {'channelId': 'UCvceBgMIpKb4zK1ss-Sh90w',
#                         'channelTitle': 'Google Search Stories',
#                         'description': 'Andrew Willis built a skatepark in '
#                                        'East London using reclaimed materials '
#                                        'left over from the Olympic Games, '
#                                        'creating a lasting legacy for the '
#                                        'local community of Hackney Wick.',
#                         'playlistId': 'PLBCF2DAC6FFB574DE',
#                         'position': 0,
# ...

# %%
# !pip install google-api-python-client
import googleapiclient.discovery
import pprint
import googleapiclient.errors

api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=api_)

request = youtube.videos().list(
    part="snippet,contentDetails,statistics",
    id="UUnjU1FHmao9YNfPzE039YTw"
)
response = request.execute()
pprint.pprint(response)
# Out:
# ...
# {'etag': 'YIUPVpqNjppyCWOZfL-19bLb7uk',
#  'items': [],
#  'kind': 'youtube#videoListResponse',
#  'pageInfo': {'resultsPerPage': 0, 'totalResults': 0}}
